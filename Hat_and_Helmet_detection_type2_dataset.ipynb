# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.2/663.2 kB 4.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO

# %%
model=YOLO('yolov8m.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 123MB/s]

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/My_project/DATASET/yolov8_custom_data/data.yaml epochs=3

# %%
model.train(data="/content/drive/MyDrive/yolov8/data.yaml", epochs=10)
# Out:
# Ultralytics YOLOv8.0.231 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
infer=YOLO('/content/runs/detect/train2/weights/best.pt')

# %%
infer.predict('/content/drive/MyDrive/yolov8/v1 (1).mp4',save = True, save_txt= True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/4196) /content/drive/MyDrive/yolov8/v1 (1).mp4: 384x640 (no detections), 44.8ms
# video 1/1 (2/4196) /content/drive/MyDrive/yolov8/v1 (1).mp4: 384x640 (no detections), 31.7ms
# video 1/1 (3/4196) /content/drive/MyDrive/yolov8/v1 (1).mp4: 384x640 (no detections), 51.6ms
# video 1/1 (4/4196) /content/drive/MyDrive/yolov8/v1 (1).mp4: 384x640 (no detections), 10.1ms
# ...

# %%
infer.predict('/content/drive/MyDrive/yolov8/1 (2).jpeg',save = True, save_txt= True)
# Out:
# image 1/1 /content/drive/MyDrive/yolov8/1 (2).jpeg: 448x640 (no detections), 38.4ms
# Speed: 13.5ms preprocess, 38.4ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict2
# 0 label saved to runs/detect/predict2/labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'hat', 1: 'jacket'}
#  orig_img: array([[[248, 248, 248],
#          [248, 248, 248],
#          [248, 248, 248],
#          ...,
#          [190, 175, 156],
#          [191, 174, 153],
#          [191, 174, 153]],
#
#         [[248, 248, 248],
#          [248, 248, 248],
#          [248, 248, 248],
#          ...,
#          [192, 177, 158],
#          [194, 177, 156],
#          [193, 176, 155]],
#
#         [[248, 248, 248],
#          [248, 248, 248],
#          [248, 248, 248],
#          ...,
#          [196, 181, 162],
#          [196, 181, 162],
# ...

# %%
infer.predict('/content/drive/MyDrive/yolov8/2.jpeg',save = True, save_txt= True)
# Out:
# image 1/1 /content/drive/MyDrive/yolov8/2.jpeg: 480x640 (no detections), 32.2ms
# Speed: 2.2ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict2
# 0 label saved to runs/detect/predict2/labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'hat', 1: 'jacket'}
#  orig_img: array([[[ 54,  61,  58],
#          [ 43,  50,  47],
#          [ 44,  51,  48],
#          ...,
#          [119, 117, 117],
#          [ 47,  42,  43],
#          [ 57,  52,  53]],
#
#         [[ 67,  74,  71],
#          [ 43,  50,  47],
#          [ 30,  37,  34],
#          ...,
#          [113, 111, 111],
#          [ 48,  43,  44],
#          [ 56,  51,  52]],
#
#         [[ 46,  53,  50],
#          [ 33,  40,  37],
#          [ 43,  50,  47],
#          ...,
#          [102, 100, 100],
#          [ 49,  44,  45],
# ...
